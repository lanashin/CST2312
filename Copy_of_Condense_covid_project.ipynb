# %% [markdown]
# <a href="https://colab.research.google.com/github/lanashin/CST2312/blob/main/Copy_of_Condense_covid_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Shaolong Lin, Jasmine Garnett, and Lana Shindler

# %% [markdown]
# # Question:
# Is it safe to come to US during november 2021?

# %% [markdown]
# ### Environment Set up
# Import all required libraries that are needed for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

from IPython.core.pylabtools import figsize
import matplotlib.pyplot as plot

# %% [markdown]
# ### Data Collection
# Decided in the group to use "owid-covid-data" github repository as a raw data source to collect the covid 19 data in real time and ingest it into colab notebook for data anlysis purpose

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent  ... excess_mortality excess_mortality_cumulative_per_million
# 0      AFG      Asia  ...              NaN                                     NaN
# 1      AFG      Asia  ...              NaN                                     NaN
# 2      AFG      Asia  ...              NaN                                     NaN
# 3      AFG      Asia  ...              NaN                                     NaN
# 4      AFG      Asia  ...              NaN                                     NaN
#
# [5 rows x 67 columns]

# %%
#wanted to check how many raws and columns this dataframe has, shows 137839 rows and 67 columns
df.shape
# Out:
# (148562, 67)

# %%
#to inspect the names of columns in data
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# # Performing Data Cleaning
# Replacing missing value NaN
#
# Missing values NaN can be detected by running us_df.isna().sum()

# %%
# Making each column in the database a variable to be use later.
new_deaths_smoothed = df['new_deaths_smoothed']
total_cases = df['total_cases'] # Changed 'us_cases' to 'us_total_cases'.
total_deaths = df['total_deaths']
dates = df['date']
new_cases_smoothed = df['new_cases_smoothed']
new_vaccinations_smoothed = df['new_vaccinations_smoothed']
total_vaccinations  = df['total_vaccinations']
population = df['population']
population_density = df['population_density']

# Added for deletion
new_cases = df['new_cases']
new_deaths = df['new_deaths']
total_cases_per_million = df['total_cases_per_million']
new_cases_per_million = df['new_cases_per_million']
new_cases_smoothed_per_million = df['new_cases_smoothed_per_million']
total_deaths_per_million = df['total_deaths_per_million']
new_deaths_per_million = df['new_deaths_per_million']
new_deaths_smoothed_per_million = df['new_deaths_smoothed_per_million']
reproduction_rate = df['reproduction_rate']
icu_patients = df['icu_patients']
icu_patients_per_million = df['icu_patients_per_million']
hosp_patients = df['hosp_patients']
hosp_patients_per_million = df['hosp_patients_per_million']
weekly_icu_admissions = df['weekly_icu_admissions']
weekly_icu_admissions_per_millionweekly = df['weekly_icu_admissions_per_million']
weekly_hosp_admissions = df['weekly_hosp_admissions']
weekly_hosp_admissions_per_million = df['weekly_hosp_admissions_per_million']
new_tests = df['new_tests']
total_tests = df['total_tests']
total_tests_per_thousand = df['total_tests_per_thousand']
new_tests_per_thousand = df['new_tests_per_thousand']
new_tests_smoothed = df['new_tests_smoothed']
new_tests_smoothed_per_thousand = df['new_tests_smoothed_per_thousand']
positive_rate = df['positive_rate']
tests_per_case = df['tests_per_case']
tests_units = df['tests_units']
total_vaccinations  = df['total_vaccinations']
people_vaccinated = df['people_vaccinated']
people_fully_vaccinated	 = df['people_fully_vaccinated']
total_boosters = df['total_boosters']
new_vaccinations = df['new_vaccinations']
total_vaccinations_per_hundred = df['total_vaccinations_per_hundred']
people_vaccinated_per_hundred = df['people_vaccinated_per_hundred']
people_fully_vaccinated_per_hundred = df['people_fully_vaccinated_per_hundred']
total_boosters_per_hundred = df['total_boosters_per_hundred']
new_vaccinations_smoothed_per_million = df['new_vaccinations_smoothed_per_million']
new_people_vaccinated_smoothed = df['new_people_vaccinated_smoothed']
new_people_vaccinated_smoothed_per_hundred = df['new_people_vaccinated_smoothed_per_hundred']
stringency_index = df['stringency_index']

median_age = df['median_age']
aged_65_older = df['aged_65_older']
aged_70_older = df['aged_70_older']
gdp_per_capita	 = df['gdp_per_capita']
extreme_poverty = df['extreme_poverty']
cardiovasc_death_rate = df['cardiovasc_death_rate']
diabetes_prevalence = df['diabetes_prevalence']
female_smokers = df['female_smokers']
male_smokers = df['male_smokers']
handwashing_facilities = df['handwashing_facilities']
hospital_beds_per_thousand = df['hospital_beds_per_thousand']
life_expectancy = df['life_expectancy']
human_development_index = df['human_development_index']
excess_mortality_cumulative_absolute = df['excess_mortality_cumulative_absolute']
excess_mortality_cumulative = df['excess_mortality_cumulative']
excess_mortality = df['excess_mortality']
excess_mortality_cumulative_per_million = df['excess_mortality_cumulative_per_million']

# %%
# All the deleted columns for first open data.
#del df['new_cases_smoothed']
del df['new_deaths']
#del df['new_deaths_smoothed']
#del df['total_cases_per_million']
del df['new_cases_per_million']
#del df['new_cases_smoothed_per_million']
#del df['total_deaths_per_million']
del df['new_deaths_per_million']
del df['new_deaths_smoothed_per_million']
del df['reproduction_rate']
del df['icu_patients']
del df['icu_patients_per_million']
del df['hosp_patients']
del df['hosp_patients_per_million']
del df['weekly_icu_admissions']
del df['weekly_icu_admissions_per_million']
del df['weekly_hosp_admissions']
del df['weekly_hosp_admissions_per_million']
del df['new_tests']
del df['total_tests']
del df['total_tests_per_thousand']
del df['new_tests_per_thousand']
del df['new_tests_smoothed']
del df['new_tests_smoothed_per_thousand']
del df['positive_rate']
del df['tests_per_case']
del df['tests_units']
#del df['total_vaccinations']
del df['people_vaccinated']
del df['people_fully_vaccinated']
del df['total_boosters']
del df['new_vaccinations']
#del df['new_vaccinations_smoothed']
del df['total_vaccinations_per_hundred']
del df['people_vaccinated_per_hundred']
del df['people_fully_vaccinated_per_hundred']
del df['total_boosters_per_hundred']
del df['new_vaccinations_smoothed_per_million']
del df['new_people_vaccinated_smoothed']
del df['new_people_vaccinated_smoothed_per_hundred']
del df['stringency_index']
#del df['population']
#del df['population_density']
del df['median_age']
del df['aged_65_older']
del df['aged_70_older']
del df['gdp_per_capita']
del df['extreme_poverty']
del df['cardiovasc_death_rate']
del df['diabetes_prevalence']
del df['female_smokers']
del df['male_smokers']
del df['handwashing_facilities']
del df['hospital_beds_per_thousand']
del df['life_expectancy']
del df['human_development_index']
del df['excess_mortality_cumulative_absolute']
del df['excess_mortality_cumulative']
del df['excess_mortality']
del df['excess_mortality_cumulative_per_million']

# Doing a check up if most of the colums are deleted.

# %%
# Replacing NaN from with Zero in 'new_deaths_smoothed'.
# Replacing NaN from with Zero in 'total_deaths'.
# Replacing NaN from with Zero in 'new_cases'.
# Replacing NaN from with Zero in 'total_vaccinations'.
# Replacing NaN from with Zero in 'new_vaccinations'.

df['new_deaths_smoothed'] = df['new_deaths_smoothed'].fillna(0)
df['total_deaths'] = df['total_deaths'].fillna(0)
df['new_cases_smoothed'] = df['new_cases_smoothed'].fillna(0)
df['total_vaccinations'] = df['total_vaccinations'].fillna(0)
df['new_vaccinations_smoothed'] = df['new_vaccinations_smoothed'].fillna(0)
df['new_cases_smoothed'] = df['new_cases_smoothed'].fillna(0)
df['new_cases_smoothed_per_million'] = df['new_cases_smoothed_per_million'].fillna(0)

# %%
# Changing 'date' from a object datatype to a datatime datatype.
# The 'date' need to be a datatime datatype for the next step.
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148562 entries, 0 to 148561
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   iso_code                        148562 non-null  object
#  1   continent                       139594 non-null  object
#  2   location                        148562 non-null  object
#  3   date                            148562 non-null  datetime64[ns]
#  4   total_cases                     145962 non-null  float64
#  5   new_cases                       145956 non-null  float64
#  6   new_cases_smoothed              148562 non-null  float64
#  7   total_deaths                    148562 non-null  float64
#  8   new_deaths_smoothed             148562 non-null  float64
#  9   total_cases_per_million         145280 non-null  float64
#  10  new_cases_smoothed_per_million  148562 non-null  float64
# ...

# %%
# Create a new column name 'year_and_month'.
#df['year_and_month'] = df['date'].dt.strftime('%Y-%m')
df['year'] = df['date'].dt.strftime('%Y')

# Make sure 'us_df' display only '2021'.
#df = df[df['year_and_month']=='2021-11']
df = df[df['year']=='2021']

# Checking to see if the new column is there.
print(df)
df
# Out:
#        iso_code continent     location  ...  population  population_density  year
# 312         AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 313         AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 314         AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 315         AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 316         AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# ...         ...       ...          ...  ...         ...                 ...   ...
# 148557      ZWE    Africa     Zimbabwe  ...  15092171.0              42.729  2021
# 148558      ZWE    Africa     Zimbabwe  ...  15092171.0              42.729  2021
# 148559      ZWE    Africa     Zimbabwe  ...  15092171.0              42.729  2021
# 148560      ZWE    Africa     Zimbabwe  ...  15092171.0              42.729  2021
# ...

# %% [markdown]
# ### Data Wrangling and EDA (Exploratory Data Analysis)

# %%
# Creating a Covid valuable excluding data from the USA
df_non_us = df[df.iso_code !='United States']

# %%
df_non_us.head()
# Out:
#     iso_code continent     location  ...  population  population_density  year
# 312      AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 313      AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 314      AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 315      AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
# 316      AFG      Asia  Afghanistan  ...  39835428.0              54.422  2021
#
# [5 rows x 17 columns]

# %%
#we want to chose to focus just on the usa location, it gives us 690 rows
# The 'location' column shows us all the names of places the data is from. 
# Here we block out all the data other than United States/USA. Lowering our original 137,839 rows to 690 rows.
us_df = df[df['location']=='United States']
#print(us_df)

# %%
us_df.isna().sum()
# Out:
# iso_code                          0
# continent                         0
# location                          0
# date                              0
# total_cases                       0
# new_cases                         0
# new_cases_smoothed                0
# total_deaths                      0
# new_deaths_smoothed               0
# total_cases_per_million           0
# new_cases_smoothed_per_million    0
# total_deaths_per_million          0
# total_vaccinations                0
# new_vaccinations_smoothed         0
# population                        0
# population_density                0
# year                              0
# dtype: int64

# %%
# Checking to see if everything is working correctly.
# '2021-1-01' to '2021-1-05'
us_df.head()
# Out:
#        iso_code      continent  ... population_density  year
# 140791      USA  North America  ...             35.608  2021
# 140792      USA  North America  ...             35.608  2021
# 140793      USA  North America  ...             35.608  2021
# 140794      USA  North America  ...             35.608  2021
# 140795      USA  North America  ...             35.608  2021
#
# [5 rows x 17 columns]

# %%
# Checking to see if everything is working correctly.
us_df.tail()
# Out:
#        iso_code      continent  ... population_density  year
# 141139      USA  North America  ...             35.608  2021
# 141140      USA  North America  ...             35.608  2021
# 141141      USA  North America  ...             35.608  2021
# 141142      USA  North America  ...             35.608  2021
# 141143      USA  North America  ...             35.608  2021
#
# [5 rows x 17 columns]

# %%
#plt.figure(figsize=(15,10))
#plt.bar(x=us_dates, height=us_new_cases, color='red')
#plt.xticks(rotation=50)


#plt.show()

# %%
us_new_deaths_smoothed_30 = us_df['new_deaths_smoothed'][-49:-18]
us_total_deaths_30 = us_df['total_deaths'][-49:-18]
us_dates_30 = us_df['date'][-49:-18]
us_new_cases_smoothed_30 = us_df['new_cases_smoothed'][-49:-18]
us_new_vaccinations_smoothed_30 = us_df['new_vaccinations_smoothed'][-49:-18]

# %%
# Bar graph representation of 'new cases' in November to December.
plt.figure(figsize=(15,7))
plt.bar(x = us_dates_30, height = us_new_cases_smoothed_30, color='red')
plt.xticks(rotation=90)
plt.title("Numbers of New Cases")
plt.xlabel("Month")
plt.ylabel("Number of cases")
plt.show()

# Here we show the total amount of 'New Cases' in November.
print("The Total Number of 'new cases' in November:")
us_df['new_cases_smoothed'].sum()
# Out:
# The Total Number of 'new cases' in November:
# 30990402.429

# %%
none_us_new_deaths_smoothed_30 = df_non_us['new_deaths_smoothed'][-49:-18]
none_us_total_deaths_30 = df_non_us['total_deaths'][-49:-18]
none_us_dates_30 = df_non_us['date'][-49:-18]
none_us_new_cases_smoothed_30 = df_non_us['new_cases_smoothed'][-49:-18]
none_us_new_vaccinations_smoothed_30 = df_non_us['new_vaccinations_smoothed'][-49:-18]

# %%
# Bar graph representation of 'new cases' in November to December.
plt.figure(figsize=(15,7))
plt.bar(x = us_dates_30, height = none_us_new_cases_smoothed_30, color='red')
plt.xticks(rotation=90)
plt.title("Numbers of New Cases")
plt.xlabel("Month")
plt.ylabel("Number of cases")
plt.show()

# Here we show the total amount of 'New Cases' in November.
print("The Total Number of 'new cases' in November:")
df_non_us['new_cases_smoothed'].sum()
# Out:
# The Total Number of 'new cases' in November:
# 801076888.6279999

# %%
# Basic information in 
us_df['new_cases_smoothed'].describe()
# Out:
# count       353.000000
# mean      87791.508297
# std       55619.683378
# min       11433.143000
# 25%       52717.571000
# 50%       73302.143000
# 75%      121140.429000
# max      251990.857000
# Name: new_cases_smoothed, dtype: float64

# %%
# Line graph representation of 'new cases' in November.
plt.figure(figsize=(20,7))
plt.plot(us_dates_30, us_new_cases_smoothed_30)
plt.title("Numbers of New Cases")
plt.xlabel("Month of November")
plt.ylabel("Amount of people")
plt.show()

# %%
# Gathering up all the 'new_cases' in November.
# Gathering up all the 'new_vaccinations' in November.
new_c = us_df['new_cases_smoothed'].sum()
new_v = us_df['new_vaccinations_smoothed'].sum()
print(new_v)

# Divide November vaccination counts by November case count.
# Rounding the final answer to the nearest tenth.
nov_difference = (round(new_v/new_c , 2))
print("Individual who was Newly vaccinated was", nov_difference ,"times the amount of new cases in November.")
# Out:
# 489314355.0
# Individual who was Newly vaccinated was 15.79 times the amount of new cases in November.

# %%
# Getting the 'total_cases' by the end of November.
# Getting the 'total_vaccinations' by the end of November.
total_c = us_df['total_cases'].max()
total_v = us_df['total_vaccinations'].max()

# Divide 'total_vaccination' by 'total_case'.
# Rounding the final answer to the nearest tenth.
nov_total_difference = (round(total_v/total_c , 2))
print("Individual who was vaccinated was", nov_total_difference ,"times the amount of cases by the end of November.")
# Out:
# Individual who was vaccinated was 9.74 times the amount of cases by the end of November.

# %%
us_df['mortality_percentage'] = us_df['total_deaths_per_million'] / us_df['total_cases_per_million'] * 100
us_df['mortality_percentage']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 140791    1.740985
# 140792    1.728612
# 140793    1.718610
# 140794    1.713176
# 140795    1.711491
#             ...
# 141139    1.593833
# 141140    1.591731
# 141141    1.589217
# 141142    1.587958
# 141143    1.586017
# Name: mortality_percentage, Length: 353, dtype: float64
